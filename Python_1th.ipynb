# %% [markdown]
# <a href="https://colab.research.google.com/github/palichi/Python_1th_week/blob/main/Python_1th.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = "Tom"
print("이름:", name)

# %%
side = 5   # 한 변의 길이
area = side * side
print("정사각형의 넓이:", area)

# %%
side = int(input("한 변의 길이 입력: "))
print("넓이:", side * side)

# %%
a = 10
b = 3

print("덧셈:", a + b)
print("뺄셈:", a - b)
print("곱셈:", a * b)
print("나눗셈:", a / b)

# %%
a = int(input("첫 번째 숫자: "))
b = int(input("두 번째 숫자: "))

print("덧셈:", a + b)
print("뺄셈:", a - b)
print("곱셈:", a * b)
print("나눗셈:", a / b)

# %%
age = 15
next_age = age + 1
print("내년 나이는", next_age, "살 입니다.")

# %%
print(f"내년 나이는 {age + 1}살 입니다.")

# %%
age = int(input("현재 나이 입력: "))
print(f"내년 나이는 {age + 1}살 입니다.")
